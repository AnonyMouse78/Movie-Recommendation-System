# %%
import numpy as np
import pandas as pd
import re
import ipywidgets as widgets
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import display

# %%
movies = pd.read_csv("movies.csv")
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Clean the dataset

def clean_title(title):
    return re.sub("^a-zA-Z0-9 ", "", title)

movies["clean_title"] = movies["title"].apply(clean_title)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                           clean_title
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)

# %%
# Create a TFIDF matrix 

# Term Frequency - Inverse Document Frequency

vectorizer = TfidfVectorizer(ngram_range=(1,2))

tfidf = vectorizer.fit_transform(movies["clean_title"])

tfidf
# Out:
# <62423x169249 sparse matrix of type '<class 'numpy.float64'>'
# 	with 448216 stored elements in Compressed Sparse Row format>

# %%
# Create a search function (Cosine Similarity) to compute similarity btw the entered movie & all movies in list

def search(title):
    #title = "Men 1995"
    title = clean_title(title)
    query_vec = vectorizer.transform([title])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]  # 5 most similar titles(indices) to search query
    results = movies.iloc[indices].iloc[::-1]  # Map indices to movie titles
    return results

# %%
# Develop the interactive widgets!

movie_input = widgets.Text(
    value = "Toy Story",
    description = "Movie Title:",
    disabled = False
)

movie_list = widgets.Output()

def on_type(data):
    with movie_list:  #Output widget
        movie_list.clear_output()
        title = data["new"]
        #if len(title) > 5:
        display(search(title))

movie_input.observe(on_type, names='value') #Hook input widget to on_type funcn

display(movie_input, movie_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()

# %% [markdown]
# ## Moving on to the recommendation part after analysing the input movie title

# %%
ratings = pd.read_csv("ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
# Users who like the same movie based on ratings

movie_id = 1
# people who watched toy story & people who liked toy story(rating >4)
similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
#similar_users.sum() #-> 1096044394 @ rating == 5
#similar_users.sum() #-> 3062084053 @ rating >= 4
#similar_users.sum() #-> 1525929226 @ rating > 4

# %%
# Finding other movies that the people who watched the input movie liked

similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]
similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
similar_user_recs = similar_user_recs[similar_user_recs > .1]
similar_user_recs

# 113 movies that users similar to us liked
# Out:
# movieId
# 1        1.000000
# 318      0.445607
# 260      0.403770
# 356      0.370215
# 296      0.367295
#            ...
# 953      0.103053
# 551      0.101195
# 1222     0.100876
# 745      0.100345
# 48780    0.100186
# Name: count, Length: 113, dtype: float64

# %%
# Finding how many people from all the dataset like these movies(top 113 here)

#Anyone who rated/watched a movie in similar_recs & Anyone who rateda movie >4 in similar_recs

all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
all_users
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 29             1     4973     4.5  1147869080
# 48             1     7361     5.0  1147880055
# 72             2      110     5.0  1141416589
# 76             2      260     5.0  1141417172
# ...          ...      ...     ...         ...
# 25000062  162541     5618     4.5  1240953299
# 25000065  162541     5952     5.0  1240952617
# 25000078  162541     7153     5.0  1240952613
# 25000081  162541     7361     4.5  1240953484
# 25000090  162541    50872     4.5  1240953372
#
# [1727573 rows x 4 columns]

# %%
# % of all users that recommended movies in similar_user_recs
all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())
all_user_recs
# Out:
# movieId
# 318      0.342220
# 296      0.284674
# 2571     0.244033
# 356      0.235266
# 593      0.225909
#            ...
# 551      0.040918
# 50872    0.039111
# 745      0.037031
# 78499    0.035131
# 2355     0.025091
# Name: count, Length: 113, dtype: float64

# %%
# Create a recommendation score by comparing both %'s {similar_user_recs & all_user_recs}

rec_percentages = pd.concat([similar_user_recs, all_user_recs], axis=1)
rec_percentages.columns = ["similar", "all"]
rec_percentages
# Out:
#           similar       all
# movieId
# 1        1.000000  0.124728
# 318      0.445607  0.342220
# 260      0.403770  0.222207
# 356      0.370215  0.235266
# 296      0.367295  0.284674
# ...           ...       ...
# 953      0.103053  0.045792
# 551      0.101195  0.040918
# 1222     0.100876  0.066877
# 745      0.100345  0.037031
# 48780    0.100186  0.068314
#
# [113 rows x 2 columns]

# %%
# Larger the diff/score, better recommendation it is!

rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
rec_percentages = rec_percentages.sort_values("score", ascending=False)
rec_percentages.head(10).merge(movies, left_index=True, right_on="movieId")
# Out:
#         similar       all     score  movieId                        title  \
# 0      1.000000  0.124728  8.017414        1             Toy Story (1995)
# 3021   0.280648  0.053706  5.225654     3114           Toy Story 2 (1999)
# 2264   0.110539  0.025091  4.405452     2355         Bug's Life, A (1998)
# 14813  0.152960  0.035131  4.354038    78499           Toy Story 3 (2010)
# 4780   0.235147  0.070811  3.320783     4886        Monsters, Inc. (2001)
# 580    0.216618  0.067513  3.208539      588               Aladdin (1992)
# 6258   0.228139  0.072268  3.156862     6377          Finding Nemo (2003)
# 587    0.179400  0.059977  2.991150      595  Beauty and the Beast (1991)
# 8246   0.203504  0.068453  2.972889     8961      Incredibles, The (2004)
# 359    0.253411  0.085764  2.954762      364        Lion King, The (1994)
#
#                                                  genres  \
# 0           Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
# Build a recommendation function:

def find_similar_movies(movie_id):
    
    # Users similar to us!
    similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
    similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]
    
    # Recommendations from over 10% users
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
    similar_user_recs = similar_user_recs[similar_user_recs > .10]
    
    # Common recommendations among all users
    all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
    all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())
    
    # Create and sort score
    rec_percentages = pd.concat([similar_user_recs, all_user_recs], axis=1)
    rec_percentages.columns = ["similar", "all"]    
    rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
    rec_percentages = rec_percentages.sort_values("score", ascending=False)
    
    return rec_percentages.head(10).merge(movies, left_index=True, right_on="movieId")[["score", "title", "genres"]]

# %%
movie_name_input = widgets.Text(
    value='Toy Story',
    description='Movie Title:',
    disabled=False
)
recommendation_list = widgets.Output()

def on_type(data):
    with recommendation_list:
        recommendation_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            results = search(title)
            movie_id = results.iloc[0]["movieId"]
            display(find_similar_movies(movie_id))

movie_name_input.observe(on_type, names='value')

display(movie_name_input, recommendation_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()
